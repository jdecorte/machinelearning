# %%
# Importing the necessary packages
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Data Frame
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt                     # Basic visualisation
import seaborn as sns                               # Advanced data visualisation
from sklearn.model_selection import cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Diabetes

# %% [markdown]
# Read the file diabetes.csv

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jdecorte/machinelearning/main/datasets/diabetes.csv')
df.columns = ['nr_of_times_pregnant','plasma_glucose_concentration','diastolic_blood_pressure','triceps_skin_fold_thickness','serum_insulin','bmi','pedigree_function','age','diagnosis']
df.head()
# Out:
#    nr_of_times_pregnant  plasma_glucose_concentration  \
# 0                     1                            85
# 1                     8                           183
# 2                     1                            89
# 3                     0                           137
# 4                     5                           116
#
#    diastolic_blood_pressure  triceps_skin_fold_thickness  serum_insulin   bmi  \
# 0                        66                           29              0  26.6
# 1                        64                            0              0  23.3
# 2                        66                           23             94  28.1
# 3                        40                           35            168  43.1
# 4                        74                            0              0  25.6
#
#    pedigree_function  age  diagnosis
# 0              0.351   31          0
# 1              0.672   32          1
# 2              0.167   21          0
# ...

# %% [markdown]
# Get some general info about the dataset (type of each column, null values, ...)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   nr_of_times_pregnant          767 non-null    int64
#  1   plasma_glucose_concentration  767 non-null    int64
#  2   diastolic_blood_pressure      767 non-null    int64
#  3   triceps_skin_fold_thickness   767 non-null    int64
#  4   serum_insulin                 767 non-null    int64
#  5   bmi                           767 non-null    float64
#  6   pedigree_function             767 non-null    float64
#  7   age                           767 non-null    int64
#  8   diagnosis                     767 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# Is this a skewed dataset?

# %%
# Out:
# 0    500
# 1    267
# Name: diagnosis, dtype: int64

# %% [markdown]
# What is X? What is y?

# %% [markdown]
# What is X_train, y_train, X_test, y_test?

# %% [markdown]
# What is X_train, y_train, X_val, y_val?

# %% [markdown]
# What are the dimensions of X_train, X_val, X_test, y_train, y_val, y_test?

# %%
# Out:
# Shape of x_train: (520, 8)
# Shape of x_test: (116, 8)
# Shape of x_val: (131, 8)
# Shape of y_train: (520,)
# Shape of y_test: (116,)
# Shape of y_val: (131,)

# %% [markdown]
# Standardize the data before providing it as training data.
# You should only use the training data to fit the scaler transformation and use the same fitted object to transform the validation and test input data.

# %% [markdown]
# Make sure to understand the following code. We will use it to evaluate the ANN's.

# %% [markdown]
# # Avoiding Overfitting Through Regularization
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Create a small ANN model to predict the diagnosis.
# - Use 2 hidden layers (64 neurons + 128 neurons)
# - Number of epochs = 20
# - batch_size = 16
# - Adam optimizer

# %% [markdown]
# Compile the model.

# %% [markdown]
# Train the model

# %%
# Out:
# Epoch 1/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5895 - accuracy: 0.6865 - val_loss: 0.5485 - val_accuracy: 0.7634
# Epoch 2/20
# 33/33 [==============================] - 0s 1ms/step - loss: 0.4973 - accuracy: 0.7596 - val_loss: 0.5152 - val_accuracy: 0.7634
# Epoch 3/20
# 33/33 [==============================] - 0s 1ms/step - loss: 0.4672 - accuracy: 0.7673 - val_loss: 0.4896 - val_accuracy: 0.7557
# Epoch 4/20
# 33/33 [==============================] - 0s 1ms/step - loss: 0.4505 - accuracy: 0.7750 - val_loss: 0.4965 - val_accuracy: 0.7557
# Epoch 5/20
# 33/33 [==============================] - 0s 1ms/step - loss: 0.4423 - accuracy: 0.7885 - val_loss: 0.4969 - val_accuracy: 0.7557
# Epoch 6/20
# 33/33 [==============================] - 0s 1ms/step - loss: 0.4322 - accuracy: 0.7923 - val_loss: 0.5170 - val_accuracy: 0.7481
# Epoch 7/20
# ...

# %% [markdown]
# Evaluate the model.

# %%
# Out:
# Training set Accuracy:   0.86
# Training set Loss: 0.3379
#
# Validation set Accuracy:   0.75
# Validation set Loss: 0.5769

# %% [markdown]
# Take a look at the plot. This doesn't look any good!! Training curve and Validation are diverging. As the accuracy of the Training curve improves, the accuracy of the Validation curve goes down, which means the model is overfitting.
# Try to change some of the parameters to try to get better results: e.g. change the number of neurons, the number of layers, the batch_size, ...

# %% [markdown]
# In the section 'Avoid Overfitting Through Regularization', jin the book literally says 'Dropout is one of the most popular regularization techniques for deep neural networks'. Look at the code  that shows how Dropout is implemented and do the same for this network.
# * Create the new ANN model. Use dropout layers with rate = 0.5
# * Compile the model
# * Train the model
# * Evaluate the model

# %%
# Out:
# Epoch 1/20
# 33/33 [==============================] - 0s 6ms/step - loss: 0.6709 - accuracy: 0.6135 - val_loss: 0.5772 - val_accuracy: 0.7252
# Epoch 2/20
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5627 - accuracy: 0.7231 - val_loss: 0.5320 - val_accuracy: 0.7634
# Epoch 3/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5274 - accuracy: 0.7192 - val_loss: 0.5231 - val_accuracy: 0.7557
# Epoch 4/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5137 - accuracy: 0.7308 - val_loss: 0.5097 - val_accuracy: 0.7634
# Epoch 5/20
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4991 - accuracy: 0.7423 - val_loss: 0.5070 - val_accuracy: 0.7481
# Epoch 6/20
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4897 - accuracy: 0.7596 - val_loss: 0.5047 - val_accuracy: 0.7557
# Epoch 7/20
# ...

# %%
# Out:
# Training set Accuracy:   0.80
# Training set Loss: 0.4272
#
# Validation set Accuracy:   0.76
# Validation set Loss: 0.5076

# %% [markdown]
# If everything went well, the Training Curve and Validation Curve aren't diverging any more. Make sure you see the difference with the previous plots!
